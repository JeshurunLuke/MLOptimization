# %%
import math
a = '...'

steps =math.ceil(len(a)/6) 
print(steps)
timeperStep = 9
print(steps*timeperStep*(1/60))
# Out:
# 227
# 34.05

# %%
d = '...'

# %%
print(len(a)/len(d))
# Out:
# 2.556390977443609
